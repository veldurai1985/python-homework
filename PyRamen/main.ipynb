# %%
# @TODO: Import libraries
import csv
from pathlib import Path

# Check the current directory where the Python program is executing from
print(f"Current Working Directory: {Path.cwd()}")

# @TODO: Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path('./Resources/menu_data.csv')
sales_filepath = Path('./Resources/sales_data.csv')

# @TODO: Initialize list objects to hold our menu and sales data
menu = []
sales = []

#Initialize all the variables


# @TODO: Read in the menu data into the menu list
with open(menu_filepath, 'r') as menu_data_file:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    menu_data = csv.reader(menu_data_file, delimiter=',')

    # Storing the header data from the start of the file
    menu_header = next(menu_data)
    
    # Iterating over the menu data and loading into menu list 
    for row in menu_data: 
        # Caluclating total month 
        menu.append(row)

# @TODO: Read in the sales data into the sales list
with open(sales_filepath, 'r') as sales_data_file:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    sales_data = csv.reader(sales_data_file, delimiter=',')

    # Storing the header data from the start of the file
    sales_header = next(sales_data)
    
    # Iterating over the menu data and loading into menu list 
    for row in sales_data: 
        # Caluclating total month 
        sales.append(row)


print (sales)

# @TODO: Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
row_count = 0

# @TODO: Loop over every row in the sales list object




    # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
    # @TODO: Initialize sales data variables


    # @TODO:
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit








    # @TODO: For every row in our sales data, loop over the menu records to determine a match


        # Item,Category,Description,Price,Cost
        # @TODO: Initialize menu data variables




        # @TODO: Calculate profit of each item in the menu data


        # @TODO: If the item value in our sales data is equal to the any of the items in the menu, then begin tracking metrics for that item


            # @TODO: Print out matching menu data






            # @TODO: Cumulatively add up the metrics for each item key





        # @TODO: Else, the sales item does not equal any fo the item in the menu data, therefore no match



    # @TODO: Increment the row counter by 1


# @TODO: Print total number of records in sales data




# @TODO: Write out report to a text file (won't appear on the command line output)
# Out:
# , '12-30-2018', '6288752350766002', '1', 'shio ramen'], ['73857', '12-30-2018', '3770036311184597', '4', 'spicy miso ramen'], ['73858', '12-30-2018', '3770036311184597', '4', 'spicy miso ramen'], ['73859', '12-30-2018', '8865807323169210', '1', 'tori paitan ramen'], ['73860', '12-30-2018', '8865807323169210', '1', 'tori paitan ramen'], ['73861', '12-30-2018', '8652377986898589', '1', 'truffle butter ramen'], ['73862', '12-30-2018', '8652377986898589', '1', 'truffle butter ramen'], ['73863', '12-30-2018', '2924604449172499', '1', 'miso crab ramen'], ['73864', '12-30-2018', '2924604449172499', '1', 'miso crab ramen'], ['73865', '12-30-2018', '2479795673224135', '4', 'nagomi shoyu'], ['73866', '12-30-2018', '2479795673224135', '4', 'nagomi shoyu'], ['73867', '12-30-2018', '7187342431192237', '1', 'truffle butter ramen'], ['73868', '12-30-2018', '7187342431192237', '1', 'truffle butter ramen'], ['73869', '12-30-2018', '4627206665884368', '2', 'truffle butter ramen'], ['73870', '12-30-2018', '4627206665884368', '2', 'truffle butter ramen'], ['73871', '12-30-2018', '7913476371126522', '1', 'vegetarian curry + king trumpet mushroom ramen'], ['73872', '12-30-2018', '7913476371126522', '1', 'vegetarian curry + king trumpet mushroom ramen'], ['73873', '12-30-2018', '5441728824147974', '1', 'miso crab ramen'], ['73874', '12-30-2018', '5441728824147974', '1', 'miso crab ramen'], ['73875', '12-30-2018', '9416345701720973', '1', 'nagomi shoyu'], ['73876', '12-30-2018', '9416345701720973', '1', 'nagomi shoyu'], ['73877', '12-30-2018', '8870147602474129', '1', 'vegetarian spicy miso'], ['73878', '12-30-2018', '8870147602474129', '1', 'vegetarian spicy miso'], ['73879', '12-30-2018', '1729711219897576', '1', 'vegetarian curry + king trumpet mushroom ramen'], ['73880', '12-30-2018', '1729711219897576', '1', 'vegetarian curry + king trumpet mushroom ramen'], ['73881', '12-30-2018', '7621179723726074', '1', 'tori paitan ramen'], ['73882', '12-30-2018', '7621179723726074', '1', 'tori paitan ramen'], ['73883', '12-30-2018', '2241025691021837', '1', 'tonkotsu ramen'], ['73884', '12-30-2018', '2241025691021837', '1', 'tonkotsu ramen'], ['73885', '12-30-2018', '3403276542971431', '1', 'nagomi shoyu'], ['73886', '12-30-2018', '3403276542971431', '1', 'nagomi shoyu'], ['73887', '12-30-2018', '8096698515647224', '1', 'soft-shell miso crab ramen'], ['73888', '12-30-2018', '8096698515647224', '1', 'soft-shell miso crab ramen'], ['73889', '12-30-2018', '9896073389710967', '1', 'truffle butter ramen'], ['73890', '12-30-2018', '9896073389710967', '1', 'truffle butter ramen'], ['73891', '12-30-2018', '5955302238459753', '1', 'miso crab ramen'], ['73892', '12-30-2018', '5955302238459753', '1', 'miso crab ramen'], ['73893', '12-30-2018', '7314077148821758', '3', 'spicy miso ramen'], ['73894', '12-30-2018', '7314077148821758', '3', 'spicy miso ramen'], ['73895', '12-30-2018', '9785078736740353', '3', 'vegetarian curry + king trumpet mushroom ramen'], ['73896', '12-30-2018', '9785078736740353', '3', 'vegetarian curry + king trumpet mushroom ramen'], ['73897', '12-30-2018', '8810542153931476', '1', 'spicy miso ramen'], ['73898', '12-30-2018', '8810542153931476', '1', 'spicy miso ramen'], ['73899', '12-30-2018', '5782369038056670', '1', 'spicy miso ramen'], ['73900', '12-30-2018', '5782369038056670', '1', 'spicy miso ramen'], ['73901', '12-30-2018', '8322313558517801', '1', 'truffle butter ramen'], ['73902', '12-30-2018', '8322313558517801', '1', 'truffle butter ramen'], ['73903', '12-30-2018', '9489269307972066', '1', 'burnt garlic tonkotsu ramen'], ['73904', '12-30-2018', '9489269307972066', '1', 'burnt garlic tonkotsu ramen'], ['73905', '12-30-2018', '5482452083924158', '1', 'truffle butter ramen'], ['73906', '12-30-2018', '5482452083924158', '1', 'truffle butter ramen'], ['73907', '12-30-2018', '5350457032515731', '1', 'truffle butter ramen'], ['73908', '12-30-2018', '5350457032515731', '1', 'truffle butter ramen'], ['73909', '12-30-2018', '8925144323653359', '1 ...
