# %%
# @TODO: Import libraries
import csv
from pathlib import Path

# Check the current directory where the Python program is executing from
print(f"Current Working Directory: {Path.cwd()}")

# @TODO: Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path('./Resources/menu_data.csv')
sales_filepath = Path('./Resources/sales_data.csv')

# @TODO: Initialize list objects to hold our menu and sales data
menu = []
sales = []

#Initialize all the variables


# @TODO: Read in the menu data into the menu list
with open(menu_filepath, 'r') as menu_data_file:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    menu_data = csv.reader(menu_data_file, delimiter=',')

    # Storing the header data from the start of the file
    menu_header = next(menu_data)
    
    # Iterating over the menu data and loading into menu list 
    for row in menu_data: 
        # Creating menu list 
        menu.append(row)

# @TODO: Read in the sales data into the sales list
with open(sales_filepath, 'r') as sales_data_file:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    sales_data = csv.reader(sales_data_file, delimiter=',')

    # Storing the header data from the start of the file
    sales_header = next(sales_data)
    
    # Iterating over sales data and loading into sales list 
    for row in sales_data: 
        # Creating sales list
        sales.append(row)


# @TODO: Initialize dict object to hold our key-value pairs of items and metrics

report = {}
report_intialized = {"01-count": 0, "02-revenue": 0, "03-cogs": 0, "04-profit": 0}
# Creating a menu list and menu_list_unique to identify the unique menu item
menu_list = []
menu_list_unique = []

# Initialize a row counter variable
sales_row_count = 0

# @TODO: Loop over every row in the sales list object

for row in sales:
    menu_item = row[4]
    menu_list.append(menu_item)
    sales_row_count += 1

# Loop over menu_list to identify the unique menu item based on sales data
for x in menu_list: 
    # check if exists in unique_list or not 
    if x not in menu_list_unique: 
        menu_list_unique.append(x) 

# Creating the intialized report dictionary for the menu item in sales data
for y in menu_list_unique: 
    # check if exists in unique_list or not 
    report[y] = report_intialized 

print ("/n")
print (report)
print ("/n")
print (f"Keys of the report are - {list(report.keys())}")
print ("/n")
print (f"Values of the report are - {list(report.values())}")
print ("/n")
print (f" Testing some values : {report['soft-shell miso crab ramen']['01-count']}")

#Temp one 
test_count = 0

for data in menu:
    menu_item_2 = data[0]
    print ('Type of menu items is')
    print (type(menu_item_2))
    print (f"Inside the first menu loop {menu_item_2}")
    print ("/n")
    price = float(data[3])
    cost = float(data[4])
    profit = price - cost

    item_quantity = 0
        
    for element in sales:
        sales_item_2 = element[4]
        quantity = int(element[3])
    
        if menu_item_2 == sales_item_2:
            #print (f"from the sales list {item}")
            item_quantity  += quantity
            
    print (f"Sales looping is done item quantity: {item_quantity} ")
    print (f"Sales looping is done item name : {menu_item_2} ")
    print ("/n")
    
    
    for keys in report.keys():
        if keys == menu_item_2:
            print (f"Inside the calculation loop and the item is : {menu_item_2} /n")
            report[menu_item_2]["01-count"] = item_quantity
            report[menu_item_2]["02-revenue"] = price * item_quantity
            report[menu_item_2]["03-cogs"] = cost * item_quantity
            report[menu_item_2]["04-profit"] = profit * item_quantity
            test_count += 1

            print (report[menu_item_2])
            print (f"how many times looping inside this guy {test_count}")
            print (report)

print (report)
print ("/n")
print (f"Last menu item {menu_item_2}")
    



    # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
    # @TODO: Initialize sales data variables
    # @TODO:
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit
    # @TODO: For every row in our sales data, loop over the menu records to determine a match
        # Item,Category,Description,Price,Cost
        # @TODO: Initialize menu data variables
        # @TODO: Calculate profit of each item in the menu data
        # @TODO: If the item value in our sales data is equal to the any of the items in the menu, then begin tracking metrics for that item
            # @TODO: Print out matching menu data
            # @TODO: Cumulatively add up the metrics for each item key
        # @TODO: Else, the sales item does not equal any fo the item in the menu data, therefore no match
    # @TODO: Increment the row counter by 1
# @TODO: Print total number of records in sales data
# @TODO: Write out report to a text file (won't appear on the command line output)
# Out:
# Current Working Directory: c:\Users\veldu\My space\Work folder\Boot Camp - Fin Tech\Assignment\Assignment_2\python-homework\PyRamen
# /n
# {'spicy miso ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'tori paitan ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'truffle butter ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'tonkotsu ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'vegetarian spicy miso': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'shio ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'miso crab ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'nagomi shoyu': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'soft-shell miso crab ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'burnt garlic tonkotsu ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}}
# /n
# Keys of the report are - ['spicy miso ramen', 'tori paitan ramen', 'truffle butter ramen', 'tonkotsu ramen', 'vegetarian spicy miso', 'shio ramen', 'miso crab ramen', 'nagomi shoyu', 'soft-shell miso crab ramen', 'burnt garlic tonkotsu ramen', 'vegetarian curry + king trumpet mushroom ramen']
# /n
# Values of the report are - [{'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}, {'01-count': 0, '02-revenue': 0, '03-cogs': 0, '04-profit': 0}]
# /n
#  Testing some values : 0
# Type of menu items is
# <class 'str'>
# Inside the first menu loop edamame
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : edamame
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop house salad
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : house salad
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop cucumber sunomono salad
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : cucumber sunomono salad
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop hiyashi wakame seaweed salad
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : hiyashi wakame seaweed salad
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop agedashi tofu
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : agedashi tofu
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop hiyayakko tofu
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : hiyayakko tofu
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop pork floss bao
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : pork floss bao
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop kakuni bao
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : kakuni bao
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop edamame fried gyoza (vegan)
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : edamame fried gyoza (vegan)
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop fried gyoza
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : fried gyoza
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop takoyaki
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : takoyaki
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop rock shrimp tempura
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : rock shrimp tempura
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop soft-shell crab tempura
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : soft-shell crab tempura
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop ebi katsu shrimp bao
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : ebi katsu shrimp bao
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop nagomi shoyu
# /n
# Sales looping is done item quantity: 9132
# Sales looping is done item name : nagomi shoyu
# /n
# Inside the calculation loop and the item is : nagomi shoyu /n
# {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}
# how many times looping inside this guy 1
# {'spicy miso ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'tori paitan ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'truffle butter ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'tonkotsu ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'vegetarian spicy miso': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'shio ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'miso crab ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'nagomi shoyu': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'soft-shell miso crab ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 9132, '02-revenue': 100452.0, '03-cogs': 45660.0, '04-profit': 54792.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop shio ramen
# /n
# Sales looping is done item quantity: 9180
# Sales looping is done item name : shio ramen
# /n
# Inside the calculation loop and the item is : shio ramen /n
# {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}
# how many times looping inside this guy 2
# {'spicy miso ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'tori paitan ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'truffle butter ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'tonkotsu ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'vegetarian spicy miso': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'shio ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'miso crab ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'nagomi shoyu': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'soft-shell miso crab ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 9180, '02-revenue': 100980.0, '03-cogs': 45900.0, '04-profit': 55080.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop spicy miso ramen
# /n
# Sales looping is done item quantity: 9238
# Sales looping is done item name : spicy miso ramen
# /n
# Inside the calculation loop and the item is : spicy miso ramen /n
# {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}
# how many times looping inside this guy 3
# {'spicy miso ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'tori paitan ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'truffle butter ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'tonkotsu ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'vegetarian spicy miso': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'shio ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'miso crab ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'nagomi shoyu': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'soft-shell miso crab ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 9238, '02-revenue': 110856.0, '03-cogs': 46190.0, '04-profit': 64666.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop vegetarian spicy miso
# /n
# Sales looping is done item quantity: 9216
# Sales looping is done item name : vegetarian spicy miso
# /n
# Inside the calculation loop and the item is : vegetarian spicy miso /n
# {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}
# how many times looping inside this guy 4
# {'spicy miso ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'tori paitan ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'truffle butter ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'tonkotsu ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'vegetarian spicy miso': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'shio ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'miso crab ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'nagomi shoyu': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'soft-shell miso crab ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 9216, '02-revenue': 110592.0, '03-cogs': 46080.0, '04-profit': 64512.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop miso crab ramen
# /n
# Sales looping is done item quantity: 8890
# Sales looping is done item name : miso crab ramen
# /n
# Inside the calculation loop and the item is : miso crab ramen /n
# {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}
# how many times looping inside this guy 5
# {'spicy miso ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'tori paitan ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'truffle butter ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'tonkotsu ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'vegetarian spicy miso': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'shio ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'miso crab ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'nagomi shoyu': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'soft-shell miso crab ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'burnt garlic tonkotsu ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 8890, '02-revenue': 106680.0, '03-cogs': 53340.0, '04-profit': 53340.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop soft-shell miso crab ramen
# /n
# Sales looping is done item quantity: 9130
# Sales looping is done item name : soft-shell miso crab ramen
# /n
# Inside the calculation loop and the item is : soft-shell miso crab ramen /n
# {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}
# how many times looping inside this guy 6
# {'spicy miso ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'tori paitan ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'truffle butter ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'tonkotsu ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'vegetarian spicy miso': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'shio ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'miso crab ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'nagomi shoyu': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'soft-shell miso crab ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 9130, '02-revenue': 127820.0, '03-cogs': 63910.0, '04-profit': 63910.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop tori paitan ramen
# /n
# Sales looping is done item quantity: 9156
# Sales looping is done item name : tori paitan ramen
# /n
# Inside the calculation loop and the item is : tori paitan ramen /n
# {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}
# how many times looping inside this guy 7
# {'spicy miso ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'tori paitan ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'truffle butter ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'tonkotsu ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'vegetarian spicy miso': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'shio ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'miso crab ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'nagomi shoyu': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'soft-shell miso crab ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 9156, '02-revenue': 119028.0, '03-cogs': 54936.0, '04-profit': 64092.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop tonkotsu ramen
# /n
# Sales looping is done item quantity: 9288
# Sales looping is done item name : tonkotsu ramen
# /n
# Inside the calculation loop and the item is : tonkotsu ramen /n
# {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}
# how many times looping inside this guy 8
# {'spicy miso ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'tori paitan ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'truffle butter ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'tonkotsu ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'vegetarian spicy miso': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'shio ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'miso crab ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'nagomi shoyu': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'soft-shell miso crab ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 9288, '02-revenue': 120744.0, '03-cogs': 55728.0, '04-profit': 65016.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop burnt garlic tonkotsu ramen
# /n
# Sales looping is done item quantity: 9070
# Sales looping is done item name : burnt garlic tonkotsu ramen
# /n
# Inside the calculation loop and the item is : burnt garlic tonkotsu ramen /n
# {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}
# how many times looping inside this guy 9
# {'spicy miso ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'tori paitan ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'truffle butter ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'tonkotsu ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'vegetarian spicy miso': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'shio ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'miso crab ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'nagomi shoyu': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'soft-shell miso crab ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'burnt garlic tonkotsu ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 9070, '02-revenue': 126980.0, '03-cogs': 54420.0, '04-profit': 72560.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop vegetarian curry + king trumpet mushroom ramen
# /n
# Sales looping is done item quantity: 8824
# Sales looping is done item name : vegetarian curry + king trumpet mushroom ramen
# /n
# Inside the calculation loop and the item is : vegetarian curry + king trumpet mushroom ramen /n
# {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}
# how many times looping inside this guy 10
# {'spicy miso ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'tori paitan ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'truffle butter ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'tonkotsu ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'vegetarian spicy miso': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'shio ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'miso crab ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'nagomi shoyu': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'soft-shell miso crab ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'burnt garlic tonkotsu ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 8824, '02-revenue': 114712.0, '03-cogs': 61768.0, '04-profit': 52944.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop truffle butter ramen
# /n
# Sales looping is done item quantity: 8982
# Sales looping is done item name : truffle butter ramen
# /n
# Inside the calculation loop and the item is : truffle butter ramen /n
# {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}
# how many times looping inside this guy 11
# {'spicy miso ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'tori paitan ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'truffle butter ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'tonkotsu ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'vegetarian spicy miso': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'shio ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'miso crab ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'nagomi shoyu': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'soft-shell miso crab ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'burnt garlic tonkotsu ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}}
# Type of menu items is
# <class 'str'>
# Inside the first menu loop green tea
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : green tea
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop coke
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : coke
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop black sesame ice cream
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : black sesame ice cream
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop matcha ice cream
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : matcha ice cream
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop mango mochi ice cream
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : mango mochi ice cream
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop strawberry mochi ice cream
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : strawberry mochi ice cream
# /n
# Type of menu items is
# <class 'str'>
# Inside the first menu loop black sesame creme brulee
# /n
# Sales looping is done item quantity: 0
# Sales looping is done item name : black sesame creme brulee
# /n
# {'spicy miso ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'tori paitan ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'truffle butter ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'tonkotsu ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'vegetarian spicy miso': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'shio ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'miso crab ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'nagomi shoyu': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'soft-shell miso crab ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'burnt garlic tonkotsu ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}, 'vegetarian curry + king trumpet mushroom ramen': {'01-count': 8982, '02-revenue': 125748.0, '03-cogs': 62874.0, '04-profit': 62874.0}}
# /n
# Last menu item black sesame creme brulee
